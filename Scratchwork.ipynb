# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import os
os.chdir("/workspace/undergrad_ml_assignments/data")

# %%
mdf = pd.read_csv('linked_mortality_file_1999_2000.csv') # Load mortality file
print( mdf.head() )
gdf = pd.read_sas("DEMO.xpt", format="xport") # Load demographics file
print( gdf.head() )
df = gdf.merge(mdf, on="SEQN", how="inner") # Merge mortality and demographics on SEQN variable
df.head()
# Out:
#    SEQN  ELIGSTAT  MORTSTAT  UCOD_LEADING  DIABETES  HYPERTEN  PERMTH_INT  \
# 0     1         2       NaN           NaN       NaN       NaN         NaN
# 1     2         1       1.0           6.0       0.0       0.0       177.0
# 2     3         2       NaN           NaN       NaN       NaN         NaN
# 3     4         2       NaN           NaN       NaN       NaN         NaN
# 4     5         1       0.0           NaN       NaN       NaN       244.0
#
#    PERMTH_EXM
# 0         NaN
# 1       177.0
# 2         NaN
# 3         NaN
# 4       244.0
#    SEQN  SDDSRVYR  RIDSTATR  RIDEXMON  RIAGENDR  RIDAGEYR  RIDAGEMN  RIDAGEEX  \
# 0   1.0       1.0       2.0       2.0       2.0       2.0      29.0      31.0
# 1   2.0       1.0       2.0       2.0       1.0      77.0     926.0     926.0
# 2   3.0       1.0       2.0       1.0       2.0      10.0     125.0     126.0
# 3   4.0       1.0       2.0       2.0       1.0       1.0      22.0      23.0
# ...

# %%
df['ELIGSTAT'].describe()
# Out:
# count    9965.000000
# mean        1.453889
# std         0.498499
# min         1.000000
# 25%         1.000000
# 50%         1.000000
# 75%         2.000000
# max         3.000000
# Name: ELIGSTAT, dtype: float64

# %%
df['PERMTH_INT'].describe()
# Out:
# count    5445.000000
# mean      202.314601
# std        67.137767
# min         0.000000
# 25%       194.000000
# 50%       235.000000
# 75%       242.000000
# max       250.000000
# Name: PERMTH_INT, dtype: float64

# %%
df['RIDAGEEX'].describe()
# Out:
# count    9.141000e+03
# mean     3.453502e+02
# std      2.835316e+02
# min      5.397605e-79
# 25%      1.290000e+02
# 50%      2.280000e+02
# 75%      5.500000e+02
# max      1.019000e+03
# Name: RIDAGEEX, dtype: float64

# %%
df['MORTSTAT'].describe()
# Out:
# count    5445.000000
# mean        0.307622
# std         0.461551
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         1.000000
# max         1.000000
# Name: MORTSTAT, dtype: float64

# %%
hdf = pd.read_sas("DRXTOT.xpt")
hdf[['SEQN', 'DRXTKCAL', 'DRXTPROT', 'DRXTCARB', 'DRXTTFAT', 'DRXTCHOL', 'DRXTFIBE', 'DRXTCAFF', 'DRXTALCO']].head()  # filtered for chosen columns
# Out:
#    SEQN  DRXTKCAL  DRXTPROT  DRXTCARB  DRXTTFAT  DRXTCHOL  DRXTFIBE  \
# 0   1.0   1358.88     31.96    250.36     27.24     46.55      7.41
# 1   2.0   2463.00    123.16    350.37     71.95    313.95     36.99
# 2   3.0   1517.69     40.19    233.63     49.94     86.22     11.16
# 3   4.0   1474.93     56.16    191.03     56.20    194.78      5.45
# 4   5.0   2658.14     97.13    253.98    114.52    180.57     17.28
#
#        DRXTCAFF      DRXTALCO
# 0  5.397605e-79  5.397605e-79
# 1  5.304500e+02  5.397605e-79
# 2  3.540000e+01  5.397605e-79
# 3  5.397605e-79  5.397605e-79
# 4  5.397605e-79  3.456000e+01

# %%
filtered_df = hdf[['SEQN', 'DRXTKCAL', 'DRXTPROT', 'DRXTCARB', 'DRXTTFAT', 'DRXTCHOL', 'DRXTFIBE', 'DRXTCAFF', 'DRXTALCO']]

# %%
new_df = df.merge(filtered_df, on="SEQN", how="inner") # Merge diet dataset with previously merged dataset on SEQN variable
new_df.head()
# Out:
#    SEQN  SDDSRVYR  RIDSTATR  RIDEXMON  RIAGENDR  RIDAGEYR  RIDAGEMN  RIDAGEEX  \
# 0   1.0       1.0       2.0       2.0       2.0       2.0      29.0      31.0
# 1   2.0       1.0       2.0       2.0       1.0      77.0     926.0     926.0
# 2   3.0       1.0       2.0       1.0       2.0      10.0     125.0     126.0
# 3   4.0       1.0       2.0       2.0       1.0       1.0      22.0      23.0
# 4   5.0       1.0       2.0       2.0       1.0      49.0     597.0     597.0
#
#    RIDRETH1  RIDRETH2  ...  PERMTH_INT  PERMTH_EXM  DRXTKCAL  DRXTPROT  \
# 0       4.0       2.0  ...         NaN         NaN   1358.88     31.96
# 1       3.0       1.0  ...       177.0       177.0   2463.00    123.16
# 2       3.0       1.0  ...         NaN         NaN   1517.69     40.19
# 3       4.0       2.0  ...         NaN         NaN   1474.93     56.16
# 4       3.0       1.0  ...       244.0       244.0   2658.14     97.13
#
#    DRXTCARB  DRXTTFAT  DRXTCHOL  DRXTFIBE      DRXTCAFF      DRXTALCO
# ...

# %%
missing = new_df.isnull().sum()
missing = missing[missing > 0]
missing
# Out:
# RIDAGEMN         117
# RIDAGEEX         141
# DMQMILIT        4031
# DMDBORN            5
# DMDCITZN           1
# DMDYRSUS        7520
# DMDEDUC3        5908
# DMDEDUC2        4838
# DMDEDUC         1463
# DMDSCHOL        6108
# DMDMARTL        3667
# INDHHINC        1356
# INDFMINC         137
# INDFMPIR        1313
# RIDEXPRG        7446
# RIDPREG         7453
# DMDHRGND          12
# DMDHRAGE          12
# DMDHRBRN         315
# DMDHREDU         321
# DMDHRMAR        1758
# DMDHSEDU        6261
# DMAETHN         9282
# DMARACE         9282
# MORTSTAT        4309
# UCOD_LEADING    7828
# DIABETES        7828
# HYPERTEN        7828
# PERMTH_INT      4309
# PERMTH_EXM      4309
# DRXTKCAL         557
# DRXTPROT         557
# DRXTCARB         557
# DRXTTFAT         557
# DRXTCHOL         557
# DRXTFIBE         557
# DRXTCAFF         557
# DRXTALCO         557
# dtype: int64

# %%
sns.scatterplot(new_df, x="DRXTCAFF", y="DRXTALCO", hue = "MORTSTAT")
# Out:
# <Axes: xlabel='DRXTCAFF', ylabel='DRXTALCO'>

# %%
sns.scatterplot(new_df, x="DRXTPROT", y="DRXTALCO", hue = "MORTSTAT")
# Out:
# <Axes: xlabel='DRXTPROT', ylabel='DRXTALCO'>

# %%
sns.scatterplot(new_df, x="PERMTH_INT", y="DRXTALCO", hue = "MORTSTAT")
# Out:
# <Axes: xlabel='PERMTH_INT', ylabel='DRXTALCO'>

# %% [markdown]
# note outliers (highest alcohol levels / mortstat with life expectancy)

# %%
sns.scatterplot(new_df, x="PERMTH_INT", y="DRXTCAFF", hue = "MORTSTAT")
# Out:
# <Axes: xlabel='PERMTH_INT', ylabel='DRXTCAFF'>

# %% [markdown]
# Similar to above, note outliers with caffeine intake
